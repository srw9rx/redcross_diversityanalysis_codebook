# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cvilledata = pd.read_csv("/Users/sophiawalton/Documents/cvilleall501c3.csv", sep=",", engine='python')

cvilledata = cvilledata[1:] #take the data less the header row
cvilledata.columns = columns=['n/a', 'code', 'name', 'city', 'state', 'country','given code', 'Website', 'classification']

print(cvilledata)
# Out:
#          n/a       code                                               name  \
# 1       9683   20600697                                   Angioma Alliance
# 2       9949   20629784        Albemarle County Sheriffs Office Foundation
# 3      14418   30433415                   Sunny Days Charitable Foundation
# 4      15133   30500788                  Ash Lawn Opera Charlottesville Ci
# 5      21726   43158798           National Coalition of Girls Schools Inc.
# ..       ...        ...                                                ...
# 818  1049844  843235399                                    Basics for Kids
# 819  1056261  843643390               Institute for American Media Studies
# 820  1093552  851830210     Africans United Communities of Charlottesville
# 821  1094898  852007784   Walker Buford United Parent Teacher Organization
# 822  1103229  853008335  Organization for Aet of Brazzaville Residing A...
#
#                 city state        country given code  \
# ...

# %%
#cvilledata.plot.pie(y='classification')
valuecounts = cvilledata['classification'].value_counts()

# %%
print(valuecounts)
# Out:
# None               121
# Other              115
# Foundation          79
# Education           71
# Religious           70
# Arts                63
# Medical             50
# Sports              44
# UVA                 40
# Science             33
# Youth               31
# International       29
# Housing             28
# Race                18
# Gender               9
# Law Enforcement      8
# Transportation       3
# Animal               2
# Environment          2
# Student              2
# Historical           1
# Justice              1
# Soorts               1
# Name: classification, dtype: int64

# %%
valuecounts.plot.pie(figsize=(15,20))
# Out:
# <AxesSubplot:ylabel='classification'>

# %%
valuecounts.plot.bar()
# Out:
# <AxesSubplot:>
